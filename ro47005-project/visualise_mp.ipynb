# %%
import matplotlib.pyplot as plt
import numpy as np
import json

# %matplotlib widget

# %%
def open_json(filename):
    with open(filename, 'r') as file:
        return json.load(file)

plt.figure()
plt.axis('equal')
plt.ylim(0, 1)
filenames = [
    'data/motion_primitives/1.0_1.0_0.0.json',
    'data/motion_primitives/1.0_1.0_0.2.json',
    'data/motion_primitives/1.0_1.0_0.2_curvefitted.json',
    'data/motion_primitives/1.0_1.0_0.4.json',
    'data/motion_primitives/1.0_1.0_0.4_curvefitted.json',
    'data/motion_primitives/1.0_1.0_0.6.json',
    'data/motion_primitives/1.0_1.0_0.6_curvefitted.json',
    'data/motion_primitives/1.0_1.0_0.95.json',
    'data/motion_primitives/1.0_1.0_0.95_curvefitted.json',
]
# filenames = ['data/motion_primitives/1.0_1.0_0.4.json']

for filename in filenames:
    points = open_json(filename)['points']
    points = np.array(points)
    plt.scatter(points[:, 1], points[:, 0])
    # mirror the primitive
#     plt.plot(-points[:, 1], points[:, 0])

plt.show()
# Out:
# /var/folders/l0/dbt718px5_39y4g6rwlhmpd40000gn/T/ipykernel_23730/209317147.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
